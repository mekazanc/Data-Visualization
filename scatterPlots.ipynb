# %% [markdown]
# <a href="https://colab.research.google.com/github/mekazanc/visualization/blob/master/scatterPlots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Scatter Plot
#
# I will create scatter Plots in this code.
#
# The main source is below. I added a few more codes/parameters to the reference code.
#
# https://github.com/CoreyMSchafer/code_snippets/blob/master/Python/Matplotlib/07-ScatterPlots/starting_code.py

# %%
import pandas as pd
from matplotlib import pyplot as plt

plt.style.use('seaborn')

x = [5, 7, 8, 5, 6, 7, 9, 2, 3, 4, 4, 4, 2, 6, 3, 6, 8, 6, 4, 1]
y = [7, 4, 3, 9, 1, 3, 2, 5, 2, 4, 8, 7, 1, 6, 4, 9, 7, 7, 5, 1]


colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7, 1, 2, 8, 1, 9, 2, 5, 6, 7, 5]

sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174,
          538, 239, 394, 399, 153, 273, 293, 436, 501, 397, 539]


#cmaps options I
cmaps = ['viridis', 'plasma', 'inferno', 'magma', 'cividis']
#cmap options II
cmaps= ['Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']

plt.scatter(x,y, c = colors, s = sizes, cmap = 'viridis', 
            edgecolor = 'white',linewidth= 2, alpha = 0.6)

plt.title('Scatter plot Example')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

# Select an interesting point. Give location of point and initial location of arrow. 
plt.annotate('Significant Point', xy=(5, 7), xytext=(7, 9),
# Custom arrow
arrowprops=dict(facecolor='black', shrink=0.05)
)


plt.tight_layout()
cbar = plt.colorbar()
cbar.set_label('Importance Level')
plt.show()
